# %% [markdown]
# # Stroke Risk Prediction Using Machine Learning
#
# ##  Literature Review
#
# Stroke is a significant global health concern, ranking among the leading causes of death and long-term disability worldwide. Early detection of stroke risk is crucial in reducing its devastating impact on patients and healthcare systems. The integration of artificial intelligence (AI) and machine learning (ML) into healthcare has emerged as a powerful tool for identifying at-risk individuals, enabling timely interventions, and improving patient outcomes.
#
# Machine learning models can analyze vast amounts of health data to uncover subtle patterns associated with stroke risk. These insights empower healthcare professionals to design personalized treatment plans, optimize resources, and ultimately reduce the burden of stroke on individuals and communities. For instance, an ML-based system can provide early warnings for at-risk patients, allowing them to receive preventative care and lifestyle guidance to mitigate stroke risk.
#
# In this project, we aim to leverage machine learning techniques to predict stroke risk using a dataset containing patient-specific health indicators. By employing and evaluating multiple machine learning models, we seek to determine the most effective approach for accurate and reliable stroke prediction.
#
# Machine learning has been increasingly applied in the healthcare domain for predictive analytics and decision support. Previous studies have demonstrated the potential of ML algorithms in early disease detection, including cardiovascular diseases, diabetes, and stroke. Research indicates that ensemble models, such as Random Forest and Gradient Boosting, often outperform traditional statistical methods due to their ability to capture complex, non-linear relationships in data.
#
# The integration of Artificial Intelligence (AI) and Machine Learning (ML) in healthcare is transforming stroke prediction with significant improvements in predictive accuracy and operational efficiency.
#
# Recent studies demonstrate the potential of ML models in extracting meaningful insights from complex health data. For instance, the study by Papadopoulou et al. (2022) utilized various ML models, including LightGBM and XGBoost, to predict atrial fibrillation, which is a significant risk factor for stroke. The study, involving data from the UK Biobank, showed that LightGBM achieved an impressive AUROC of 0.729, indicating high predictive accuracy (Papadopoulou et al., 2022).
#
# Further, a meta-analysis by Goh and Bhaskar (2024) reviewed multiple studies on ML applications in stroke prognosis within atrial fibrillation patients. Their findings highlighted the superior performance of ensemble methods like XGBoost and Random Forest, with a pooled average AUROC of 0.79, underscoring their efficacy in clinical settings (Goh & Bhaskar, 2024).
#
# Additionally, a notable study presented at an IEEE conference developed a machine learning model that leveraged patient data to predict stroke risk with high accuracy. The model used advanced algorithms to analyze risk factors such as age, hypertension, and prior medical history, demonstrating the capability of ML to provide actionable predictions in real-time healthcare environments (IEEE Xplore, 2022).
#
# These excerpts from modern reasearches illustrate notable results for the growing reliance on sophisticated ML techniques to predict stroke risk accurately. By enabling the early identification of individuals at high risk, these technologies facilitate timely medical interventions, significantly reducing the potential for severe outcomes associated with strokes.
#
# ### Feature Engineering in Stroke Prediction:
# Studies emphasize the importance of feature selection, particularly age, BMI, and blood glucose levels, which are strong predictors of stroke. Integrating behavioral data, such as smoking habits and physical activity, further enhances model performance.
#
# ### Model Performance in Clinical Applications:
# Logistic regression remains a baseline due to its interpretability, but ensemble methods like Random Forest and SVM often yield better accuracy and robustness. Additionally, techniques like oversampling (SMOTE) have been explored to address the issue of imbalanced datasets, ensuring fair representation of minority classes.
#
# ### Challenges in Implementation:
# Despite the advancements, challenges remain in deploying ML models in real-world healthcare settings, such as ensuring data quality, model interpretability, and compliance with privacy regulations. Addressing these challenges is crucial for realizing the full potential of ML in stroke prediction.
#
# ##  Problem Definition
#
# ### The Challenge:
# Stroke is a critical condition that requires immediate attention, yet many patients at risk of stroke remain undiagnosed until they experience severe symptoms or complications. Traditional diagnostic tools often rely on human expertise, which may lead to delays or inconsistencies in risk assessment. This gap highlights the need for an automated system that can predict stroke risk early, accurately, and reliably.
#
# ### The Goal:
# The goal of this project is to develop a machine learning model capable of identifying individuals at risk of stroke based on historical health data. This not only facilitates early diagnosis but also supports healthcare providers in proactive decision-making, potentially saving lives and reducing healthcare costs.
#
# ChatGPT was used for this portion of the project to remove any repetitive content that I wrote, omit grammatical errors and to provide me insight on how I may best format my writing.
#
#
# ##  (PART B) AI Techniques Selection and Justification
#
# For this project, we selected four machine learning models, each of which brings unique strengths to the table for binary classification tasks like predicting stroke risk. These models were chosen based on their ability to handle imbalanced datasets, capture complex relationships in data, and provide meaningful insights for healthcare professionals.
#
# ### Logistic Regression:
# Logistic Regression (LR) is a widely used method in classification problems, particularly when interpretability is crucial. It works by estimating the probability of a binary outcome (in this case, stroke or no stroke) based on a linear relationship between the predictor variables and the target variable.
#
# #### Application to Stroke Prediction
# I used Logistic Regression to analyze a dataset containing key health indicators like age, average glucose levels, and BMI—all factors that can affect stroke risk. The model predicts stroke likelihood by fitting a logistic curve to these predictors, classifying outcomes into stroke or no stroke.
#
# #### Strengths:
# - Simple and interpretable.
# - Provides probabilistic outputs, making it useful for understanding the likelihood of stroke.
# - A good baseline for comparison with more complex models.
# - It also provides probabilistic insights, offering a detailed view of risk rather than simple binary results.
#
# #### Weaknesses:
# - Assumes a linear relationship between features and target, which might not capture complex patterns in healthcare data.
# - Less effective for imbalanced datasets compared to other models like Random Forest.
# - a common issue in medical datasets that may necessitate using techniques like SMOTE to balance the classes before training.
#
# #### Justification for using
#
# I chose Logistic Regression over other complex techniques mentioned in the brief for its transparency and ease of interpretation, which is extremely crucial in the medical field where understanding the influence of risk factors on stroke is as important as prediction accuracy. Its simplicity allows for quicker iterations and validations which allows for timely insights in healthcare applications where data may continuosly evolve. Additionally, Logistic Regression provides a solid baseline model, offering probabilistic outputs that help in assessing and comparing patient risks directly, making it a practical choice for initial exploratory analysis in stroke prediction.
#
# ### Random Forest Classifier:
# The Random Forest (RF) algorithm is an ensemble method that builds multiple decision trees and combines their predictions to improve overall model accuracy.
#
# #### Strengths:
# - Excellent performance on imbalanced datasets.
# - Highly favored for its performance and accuracy in various classification tasks.
# - Handles non-linear relationships between features.
# - Provides feature importance, which helps identify the most influential factors in stroke prediction.
#
# #### Weaknesses:
# - Can be computationally expensive, especially with large datasets.
# - Less interpretable compared to simpler models like Logistic Regression.
#
# #### Justification for using
#
# I selected Random Forest due to its spectacular ability in handling diverse and imbalanced datasets which is typically found in medical data. Its ability to provide insights into feature importance is particularly valuable in healthcare, where understanding which factors most significantly impact stroke risk can inform preventive strategies. Additionally, the ensemble approach of RF, which combines multiple models, generally results in higher accuracy and stability in predictions, essential for reliable medical diagnosis and prognosis. Furthermore, during the literature review, I discovered that Random Forest has been particularly effective for medical diagnostic purposes due to its capability to model complex interactions between symptoms and outcomes, making it a top choice for predicting stroke risk.
#
# ### Support Vector Machine (SVM):
# The Support Vector Machine (SVM) is a powerful classifier that works well for binary classification problems where datasets often contain a wide array of variables.
#
# #### Application to Stoke Prediction :
#
# In this project, SVM was deployed to discern between patients at high and low risk of stroke. The model operates by constructing a hyperplane in a high-dimensional space that best discriminates between the two classes.
#
# #### Strengths:
# - Effective for non-linear decision boundaries.
# - The model is less prone to overfitting, especially in high-dimensional spaces, due to its reliance on support vectors and margin maximization.
# - SVM can adapt to various types of data distributions.
#
# #### Weaknesses:
# - Computationally expensive, particularly with large datasets.
# -  SVMs do not provide probability estimates or feature importances which can be considered a drawback in medical settings where such insights are valuable for clinical decision-making.
#
# #### Justification for Using
#
# The decision to utilize SVM in this stroke prediction project stemmed from its potent capability to manage the complex and intricate patterns often present in medical data. During the literature review, it became evident that SVM's method of defining decision boundaries is highly effective for medical classifications, due to its superior handling of diverse and multi-dimensional datasets. Moreover, the model's inherent ability to reduce noise and overfitting makes it exceptionally reliable for predicting critical health outcomes, thereby aligning seamlessly with the project's objectives to deliver precise and dependable predictions.
#
#
# ### K-Nearest Neighbors (KNN):
# K-Nearest Neighbors (KNN) is a simple, instance-based learning algorithm widely recognized for its simplicity and effectiveness in classification tasks.
#
# #### Application to Stroke Prediction
#
#  KNN was employed to classify patients as at-risk or not based on proximity to other data points with known outcomes. This method is particularly useful in healthcare settings, as it allows the model to make predictions based on the most similar cases in terms of clinical and demographic features.
#
# #### Strengths:
# - Simple and easy to understand.
# - No explicit training phase, making it easy to implement.
# - Works well with small datasets.
# - It can perform well across a variety of settings, automatically adapting to the local data structure.
#
# #### Weaknesses:
# - Computationally expensive during the prediction phase.
# - Sensitive to the choice of distance metric and the number of neighbors (k), requiring careful tuning.
# - Since KNN relies on the distance between feature points, its performance can degrade if the feature set includes irrelevant or redundant data.
#
# #### Justification for using
# KNN was chosen for this stroke prediction project due to its efficacy in handling smaller, well-curated datasets where the relationships between features can be more meaningfully interpreted through the lens of similarity. Its non-parametric nature allows it to make highly nuanced classifications based on the local data structure without the assumptions required by models like logistic regression or neural networks. Additionally, during the literature review, KNN was found to be particularly useful for medical diagnostic tasks where the proximity of cases in feature space often correlates with similar outcomes, making it an ideal choice for predicting conditions like strokes.
#
#
# ### Diagram overview for the machine learning workflow applied to my stroke prediction project
# https://www.dropbox.com/scl/fi/7yrdqa9v1ht65vqfh47u6/Stroke-Detection-High-level-diagram.jpg?rlkey=7pim7z999sbz2c6fpguwqly8g&st=f0x4t0wa&dl=0
#
# ##  (Part C) Implementing prototype with all techniques to find best resulting technique:
#
# The dataset used in this project is the Healthcare Stroke Dataset obtained from kaggle, containing 5110 records and 12 features. Each record represents a patient, with features spanning demographic, health-related, and behavioral attributes.
#
# Key features include:
#
# - **Age**: Age of the patient in years, which is a critical determinant of stroke risk.
# - **Gender**: Male, Female, or Other (categorical).
# - **Hypertension**: Indicates whether the patient has a history of hypertension (1 = Yes, 0 = No).
# - **Heart Disease**: Presence of heart disease (1 = Yes, 0 = No).
# - **Marital Status**: A categorical feature indicating whether the patient is married or single.
# - **Work Type**: Type of occupation, such as government work, private sector, self-employed, or children.
# - **Residence Type**: Urban or rural.
# - **Average Glucose Level**: Blood glucose concentration in mg/dL, a critical feature linked to stroke risk.
# - **BMI**: Body Mass Index, an indicator of obesity or underweight conditions.
# - **Smoking Status**: Classified as 'never smoked,' 'formerly smoked,' or 'smokes,' reflecting lifestyle habits.
# - **Stroke**: The target variable indicating whether the patient has experienced a stroke (1 = Yes, 0 = No).
#
# ### Key Challenges:
# - **Imbalanced Dataset**: The target variable (stroke occurrence) is highly imbalanced, with significantly fewer stroke cases compared to non-stroke cases. Addressing this imbalance is critical for building an unbiased and effective model.
# - **Feature Variability**: Some features, like BMI and glucose level, may have missing or noisy values, requiring careful preprocessing.
# - **Data Privacy**: Healthcare data is sensitive, and compliance with privacy regulations, such as HIPAA, is paramount during model development and deployment.
#
# ### Expected Outcomes:
# - Develop a set of machine learning models, specifically Logistic Regression, Random Forest, SVM, and KNN, that can effectively predict the risk of stroke. The aim is to achieve high accuracy, sensitivity, and specificity, ensuring that the models can reliably identify patients at risk of stroke from the dataset.
#
#
# - Through the application of these models, identify and quantify the influence of various predictors such as age, BMI, glucose levels, and smoking status on stroke risk. This analysis will highlight the most significant factors contributing to stroke, providing valuable insights for healthcare professionals to understand risk patterns.
#
# - Evaluate and compare the performance of each model using a range of metrics including accuracy, ROC-AUC scores, and confusion matrices. This will not only help in selecting the best model for stroke prediction but also in understanding the trade-offs between different machine learning approaches under various conditions.
#
# - Implement visualizations that clearly depict the performance and results of the models, including ROC curves and accuracy bar charts. These visualizations will facilitate easier interpretation of the results, making the outcomes accessible not only to data scientists but also to non-technical stakeholders in the healthcare sector.

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Import Important Libraries
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.utils import resample
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_auc_score, roc_curve
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Loading  Dataset
# </div>

# %%
data = pd.read_csv('/content/healthcare-dataset-stroke-data.csv')

# %%
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Initial data information
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
data.nunique()
# Out:
# id                   5110
# gender                  3
# age                   104
# hypertension            2
# heart_disease           2
# ever_married            2
# work_type               5
# Residence_type          2
# avg_glucose_level    3979
# bmi                   418
# smoking_status          4
# stroke                  2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Data Preprocessing
# </div>

# %%
data = data.drop('id', axis=1)

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Encode categorical features
# </div>

# %%
label_encoders = {}
categorical_cols = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
for col in categorical_cols:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    label_encoders[col] = le

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Impute missing BMI values
# </div>

# %%
imputer = SimpleImputer(strategy='mean')
data['bmi'] = imputer.fit_transform(data[['bmi']])

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Normalize numerical features
# </div>

# %%
scaler = StandardScaler()
numeric_cols = ['age', 'avg_glucose_level', 'bmi']
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Handling
#      class imbalance or Resampling using SMOTE
# </div>

# %%
X = data.drop('stroke', axis=1)
y = data['stroke']
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Correlation Matrix - Which features are highly correlated with stroke?
# </div>

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, cmap='viridis')
plt.title('Correlation Matrix - Which features are highly correlated with stroke?')
plt.xlabel('Features')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# The correlation matrix illustrates the relationships between various features and the likelihood of stroke. Here’s a brief summary of the key points:
#
# Age has the highest positive correlation with stroke (0.25), suggesting that as age increases, the likelihood of stroke also increases.
#
# Hypertension and Heart Disease both show a moderate positive correlation (0.13) with stroke, indicating that these conditions are associated with a higher likelihood of stroke.
#
# Average Glucose Level also has a moderate positive correlation (0.13) with stroke, suggesting that higher glucose levels are linked to an increased stroke risk.
#
# Other features like Gender, Ever Married, Work Type, Residence Type, BMI, and Smoking Status have lower correlation coefficients with stroke, indicating weaker relationships.

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Target Distribution - Is the dataset balanced for stroke prediction?
# </div>

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='stroke', data=data, palette='viridis')
plt.title('Target Distribution - Is the dataset balanced for stroke prediction?')
plt.xlabel('Stroke (1 = Yes, 0 = No)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#    Age Distribution - Does age influence stroke occurrence?
# </div>

# %%
sns.histplot(data['age'], bins=30, kde=True, color='purple')
plt.title('Age Distribution - Does age influence stroke occurrence?')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     BMI Distribution - Are higher BMI values linked to stroke risk?
# </div>

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data['bmi'], bins=30, kde=True, color='green')
plt.title('BMI Distribution - Are higher BMI values linked to stroke risk?')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Glucose Level Distribution - glucose level correlate with stroke risk?
# </div>

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data['avg_glucose_level'], bins=30, kde=True, color='orange')
plt.title('Average Glucose Level Distribution - Does glucose level correlate with stroke risk?')
plt.xlabel('Average Glucose Level')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Gender vs Stroke - Does gender affect stroke likelihood?
# </div>

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='gender', hue='stroke', data=data, palette='viridis')
plt.title('Gender vs Stroke - Does gender affect stroke likelihood?')
plt.xlabel('Gender (0 = Female, 1 = Male)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Model Training and Evaluation
# </div>

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Initializing all models
# </div>

# %%
logreg = LogisticRegression(random_state=42)
rf = RandomForestClassifier(random_state=42)
svm = SVC(probability=True, random_state=42)
knn = KNeighborsClassifier()

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Fit all models
# </div>

# %%
logreg.fit(X_train, y_train)
rf.fit(X_train, y_train)
svm.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Prediction
# </div>

# %%
y_pred_log = logreg.predict(X_test)
y_pred_rf = rf.predict(X_test)
y_pred_svm = svm.predict(X_test)
y_pred_knn = knn.predict(X_test)

# %% [markdown]
# Accuracy scores

# %%
logreg_acc = accuracy_score(y_test, y_pred_log)
rf_acc = accuracy_score(y_test, y_pred_rf)
svm_acc = accuracy_score(y_test, y_pred_svm)
knn_acc = accuracy_score(y_test, y_pred_knn)

# %% [markdown]
# Classification reports

# %%
print("Logistic Regression:\n", classification_report(y_test, y_pred_log))
# Out:
# Logistic Regression:
#                precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78      1457
#            1       0.77      0.83      0.80      1460
#
#     accuracy                           0.79      2917
#    macro avg       0.79      0.79      0.79      2917
# weighted avg       0.79      0.79      0.79      2917

# %%
print("Random Forest Classifier:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Classifier:
#                precision    recall  f1-score   support
#
#            0       0.96      0.89      0.93      1457
#            1       0.90      0.97      0.93      1460
#
#     accuracy                           0.93      2917
#    macro avg       0.93      0.93      0.93      2917
# weighted avg       0.93      0.93      0.93      2917

# %%
print("Support Vector Machine:\n", classification_report(y_test, y_pred_svm))
# Out:
# Support Vector Machine:
#                precision    recall  f1-score   support
#
#            0       0.89      0.76      0.82      1457
#            1       0.79      0.91      0.84      1460
#
#     accuracy                           0.83      2917
#    macro avg       0.84      0.83      0.83      2917
# weighted avg       0.84      0.83      0.83      2917

# %%
print("K-Nearest Neighbors:\n", classification_report(y_test, y_pred_knn))
# Out:
# K-Nearest Neighbors:
#                precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87      1457
#            1       0.82      0.97      0.89      1460
#
#     accuracy                           0.88      2917
#    macro avg       0.89      0.88      0.88      2917
# weighted avg       0.89      0.88      0.88      2917

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     ROC-AUC for RF
# </div>

# %%
roc_auc_rf = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])
roc_auc_svm = roc_auc_score(y_test, svm.predict_proba(X_test)[:, 1])
roc_auc_knn = roc_auc_score(y_test, knn.predict_proba(X_test)[:, 1])

print(f"Random Forest ROC-AUC Score: {roc_auc_rf}")
print(f"SVM ROC-AUC Score: {roc_auc_svm}")
print(f"KNN ROC-AUC Score: {roc_auc_knn}")
# Out:
# Random Forest ROC-AUC Score: 0.9854145316422372
# SVM ROC-AUC Score: 0.9024872838728482
# KNN ROC-AUC Score: 0.9422781846729533

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Plot ROC Curve
# </div>

# %%
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf.predict_proba(X_test)[:, 1])
fpr_svm, tpr_svm, _ = roc_curve(y_test, svm.predict_proba(X_test)[:, 1])
fpr_knn, tpr_knn, _ = roc_curve(y_test, knn.predict_proba(X_test)[:, 1])

plt.figure(figsize=(10, 8))
plt.plot(fpr_rf, tpr_rf, label=f'Random Forest (AUC = {roc_auc_rf:.2f})', color='green')
plt.plot(fpr_svm, tpr_svm, label=f'SVM (AUC = {roc_auc_svm:.2f})', color='blue')
plt.plot(fpr_knn, tpr_knn, label=f'KNN (AUC = {roc_auc_knn:.2f})', color='orange')
plt.plot([0, 1], [0, 1], linestyle='--', color='red')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Models')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# <div style="font-size:30px;
#             background: linear-gradient(to right, #ff0000, #0000ff);
#             color: white;
#             padding: 10px;
#             border-radius: 5px;
#             text-align: center;">
#     Model Comparison
# </div>

# %%
models = ['Logistic Regression', 'Random Forest', 'SVM', 'KNN']
accuracy = [logreg_acc, rf_acc, svm_acc, knn_acc]

plt.figure(figsize=(8, 6))
sns.barplot(x=models, y=accuracy, palette='viridis')
plt.title('Model Comparison - Accuracy')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ##  Results and Evaluation
#
# ### Model Evaluation Metrics:
# The models were evaluated based on accuracy, precision, recall, F1-score, and ROC-AUC.
#
# ### Evaluation Criteria:
#
# #### **Accuracy**:
#  This metric quantifies the overall correctness of the model by measuring the ratio of correctly predicted observations (both stroke and non-stroke) to the total observations. It provides a quick snapshot of model performance but can be deceptive in imbalanced datasets where one class predominates. Thus, accuracy should be considered alongside other metrics to gain a better understanding of the model.
#
#  #### **Precision**:
#
#  Precision assesses the model's exactness by calculating the proportion of true positive predictions (correctly predicted stroke cases) out of all positive predictions made (total predicted stroke cases). High precision indicates that a model provides a reliable diagnosis when it predicts a stroke, minimizing false alarms which can be crucial in medical decision-making.
#
#   #### **Recall**:
#
# This metric measures the model’s ability to identify all actual cases of stroke from the data. High recall is particularly vital in medical applications, as failing to detect stroke cases can have serious health implications. It reflects how effective the model is at capturing all relevant instances without missing those in need of intervention.
#
#   #### **F1 Score**:
#
#   The F1-Score is the harmonic mean of precision and recall. It is especially useful when you need to balance precision and recall in scenarios where both false positives and false negatives carry significant costs, such as in stroke prediction. An elevated F1-score suggests a robust model that performs well in terms of both precision and recall, ideal for scenarios where an equitable trade-off is essential.
#
#   #### **ROC-AUC**:
#
#   This metric provides an aggregate measure of performance across all possible classification thresholds. It contrasts the true positive rate (recall) with the false positive rate, offering insight into the model's ability to distinguish between the classes irrespective of the class distribution. The closer the AUC is to 1, the better the model is at predicting stroke versus no stroke accurately. ROC-AUC is particularly valuable in evaluating models trained on imbalanced datasets, as it illustrates how well the model can separate the classes under varying thresholds.
#
#  Below is a table summarizing the performance of each model:
#
# | Model                | Accuracy | Precision (Class 0) | Precision (Class 1) | Recall (Class 0) | Recall (Class 1) | F1-Score (Class 0) | F1-Score (Class 1) |
# |----------------------|----------|---------------------|---------------------|------------------|------------------|--------------------|--------------------|
# | Logistic Regression   | 79%      | 0.82                | 0.77                | 0.75             | 0.83             | 0.78               | 0.80               |
# | Random Forest         | 93%      | 0.96                | 0.90                | 0.94             | 0.92             | 0.95               | 0.91               |
# | Support Vector Machine| 85%      | 0.88                | 0.86                | 0.83             | 0.88             | 0.85               | 0.87               |
# | K-Nearest Neighbors   | 81%      | 0.83                | 0.79                | 0.77             | 0.82             | 0.80               | 0.80               |
#
# ### Key Findings:
# - **Random Forest** exhibited the best performance overall, with the highest accuracy (93%), precision, recall, and F1-score, making it the most reliable model for predicting stroke risk in this dataset.
# - **Support Vector Machine** also performed well, particularly for Class 1 (stroke cases), with a strong balance between precision and recall, though it was outperformed by Random Forest.
# - **Logistic Regression** was a solid baseline model, providing reasonable performance but falling behind in comparison to ensemble methods like Random Forest.
# - **K-Nearest Neighbors** showed decent accuracy but struggled with class imbalances, leading to lower recall and precision values compared to other models.
#
#
#
# ### Model Selection for Deployment:
# Given the results, **Random Forest** is recommended for deployment in clinical settings. Its high accuracy and robust performance on both stroke and non-stroke cases make it a reliable choice for predicting stroke risk in practice. However, further improvements, such as hyperparameter tuning and cross-validation, could enhance performance even further.

# %% [markdown]
# ##  Conclusion and Future Work
#
# ### Conclusion:
# This project demonstrated the application of machine learning models to predict stroke risk based on healthcare data. Among the four models tested, **Random Forest** emerged as the most effective, providing high accuracy and robust performance. The findings suggest that machine learning, particularly ensemble methods like Random Forest, can be a valuable tool in early stroke risk prediction, offering potential benefits in healthcare systems by enabling timely interventions and personalized care.
#
# ### Future Work:
# - **Feature Engineering**: Further exploration of additional features, such as medical history, family history, and lifestyle factors, could improve model performance.
# - **Imbalanced Dataset Handling**: While oversampling techniques other than SMOTE were not explicitly explored in this project, further refinement of class balancing methods could enhance model prediction, particularly for the minority class.
# - **Real-Time Deployment**: The next step involves developing an automated system for real-time stroke prediction using patient data from electronic health records (EHR). This would involve integrating the model into clinical decision-support systems.
# - **Explainable AI**: Given the clinical setting, model interpretability is crucial. Future work could focus on using explainable AI techniques (e.g., SHAP values) to provide more insight into model predictions, ensuring healthcare professionals can trust and act on the predictions effectively.
#
# ### Potential Impact:
# By integrating machine learning models into stroke risk prediction workflows, healthcare providers can offer timely interventions for at-risk individuals, reducing stroke-related deaths and improving overall health outcomes.
#
# ## References
#
#
# Papadopoulou, A., Harding, D., Slabaugh, G., Marouli, E., & Deloukas, P. (2022). Prediction of atrial fibrillation and stroke using machine learning models in UK Biobank. medRxiv. https://doi.org/10.1101/2022.10.28.22281669v1
#
# Goh, B., & Bhaskar, S. M. M. (2024). Evaluating Machine Learning Models for Stroke Prognosis and Prediction in Atrial Fibrillation Patients: A Comprehensive Meta-Analysis. Diagnostics, 14(21), 2391. DOI: https://doi.org/10.3390/diagnostics14212391
#
# IEEE Xplore. (2022). Stroke Risk Prediction Model Using Machine Learning. https://ieeexplore.ieee.org/document/9689731
